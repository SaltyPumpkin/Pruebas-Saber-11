# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from scipy.stats import ttest_ind

# %%
Datos = pd.read_csv('C:/Users/juand/Downloads/SABER_11_2020_CSV.csv', index_col=0, sep=';', encoding='latin-1')
Saber11 = pd.DataFrame(Datos)

# %%
print('Total instances: ', Datos.shape[0]*Datos.shape[1])
# Out:
# Total instances:  30292320

# %%
Resultados = ['ESTU_COD_RESIDE_DEPTO', 'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PUNT_GLOBAL']
An_Resultados = Datos[Resultados]

# %%
An_Resultados.describe()
# Out:
#        ESTU_COD_RESIDE_DEPTO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count          504870.000000         504872.000000     504872.000000
# mean               36.099671             52.156784         51.019754
# std               613.810991             10.158427         11.647657
# min                 5.000000              0.000000          0.000000
# 25%                11.000000             45.000000         43.000000
# 50%                20.000000             52.000000         51.000000
# 75%                54.000000             59.000000         59.000000
# max             99999.000000            100.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS    PUNT_INGLES  \
# count     504872.000000             504872.000000  504538.000000
# mean          48.197373                 48.233939      46.883507
# std           10.499610                 11.970584      11.313128
# min            0.000000                  0.000000       0.000000
# ...

# %% [markdown]
# ## Puntajes promedio para el Quindío

# %%
Quindio_resultados = An_Resultados.loc[(An_Resultados['ESTU_COD_RESIDE_DEPTO'] == '63') | (An_Resultados['ESTU_COD_RESIDE_DEPTO'] == 63)]  # Quindío Code = 63
Quindio_resultados.describe()
# Out:
#        ESTU_COD_RESIDE_DEPTO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                 5810.0           5810.000000       5810.000000
# mean                    63.0             53.389673         51.971773
# std                      0.0             10.078430         11.790968
# min                     63.0              0.000000          0.000000
# 25%                     63.0             46.000000         44.000000
# 50%                     63.0             54.000000         52.000000
# 75%                     63.0             61.000000         60.000000
# max                     63.0            100.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count       5810.000000               5810.000000  5810.000000  5810.000000
# mean          49.119621                 49.425818    48.020482   253.746127
# std           10.787960                 12.144625    11.206804    49.102446
# ...

# %% [markdown]
# ## Puntajes Promedio para Antioquia

# %%
Antioquia_resultados = An_Resultados.loc[(An_Resultados['ESTU_COD_RESIDE_DEPTO'] == '5') | (An_Resultados['ESTU_COD_RESIDE_DEPTO'] == 5)]  # Antioquia Code = 5
Antioquia_resultados.describe()
# Out:
#        ESTU_COD_RESIDE_DEPTO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                70478.0          70478.000000      70478.000000
# mean                     5.0             51.852521         49.621825
# std                      0.0             10.338164         11.805077
# min                      5.0              0.000000          0.000000
# 25%                      5.0             44.000000         41.000000
# 50%                      5.0             52.000000         50.000000
# 75%                      5.0             59.000000         58.000000
# max                      5.0            100.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS   PUNT_INGLES   PUNT_GLOBAL
# count      70478.000000              70478.000000  70474.000000  70478.000000
# mean          46.621258                 47.838758     46.261543    243.870272
# std           10.445108                 12.083966     11.552551     48.935078
# ...

# %% [markdown]
# ## Puntaje promedio para Boyacá

# %%
Boyaca_resultados = An_Resultados.loc[(An_Resultados['ESTU_COD_RESIDE_DEPTO'] == '15') | (An_Resultados['ESTU_COD_RESIDE_DEPTO'] == 15)]  # Boyacá Code = 15
Boyaca_resultados.describe()
# Out:
#        ESTU_COD_RESIDE_DEPTO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                15258.0          15258.000000      15258.000000
# mean                    15.0             53.834316         54.336872
# std                      0.0              9.668379         11.026440
# min                     15.0              0.000000          0.000000
# 25%                     15.0             47.000000         47.000000
# 50%                     15.0             54.000000         55.000000
# 75%                     15.0             61.000000         62.000000
# max                     15.0            100.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS   PUNT_INGLES   PUNT_GLOBAL
# count      15258.000000              15258.000000  15258.000000  15258.000000
# mean          51.032835                 50.846048     47.961922    260.812230
# std            9.974170                 11.640947     10.585392     46.331506
# ...

# %% [markdown]
# ## Puntajes medios en todos los municipios del Quindío

# %%
Municipio = ['ESTU_COD_RESIDE_MCPIO', 'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PUNT_GLOBAL']
Quindio = Datos[Municipio]

# %% [markdown]
# ### Armenia

# %%
Quindio_Armenia_resultados = Quindio.loc[(Quindio['ESTU_COD_RESIDE_MCPIO'] == '63001') | (Quindio['ESTU_COD_RESIDE_MCPIO'] == 63001)]
Quindio_Armenia_resultados.describe()
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                 3049.0           3049.000000       3049.000000
# mean                 63001.0             55.100689         53.960315
# std                      0.0             10.010298         11.982711
# min                  63001.0             27.000000          0.000000
# 25%                  63001.0             48.000000         45.000000
# 50%                  63001.0             55.000000         54.000000
# 75%                  63001.0             62.000000         62.000000
# max                  63001.0            100.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count       3049.000000               3049.000000  3049.000000  3049.000000
# mean          51.142342                 51.531978    50.105280   263.576910
# std           11.220327                 12.500304    11.965573    50.481254
# ...

# %% [markdown]
# ### Calarcá

# %%
Quindio_Calarca_resultados = Quindio.loc[(Quindio['ESTU_COD_RESIDE_MCPIO'] == '63130') | (Quindio['ESTU_COD_RESIDE_MCPIO'] == 63130)]  # Select Calarca Code = 63130
Quindio_Calarca_resultados.describe()
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                  720.0            720.000000        720.000000
# mean                 63130.0             53.206944         52.247222
# std                      0.0              9.693937         11.387229
# min                  63130.0             28.000000         21.000000
# 25%                  63130.0             46.000000         44.000000
# 50%                  63130.0             54.000000         52.500000
# 75%                  63130.0             60.000000         60.000000
# max                  63130.0             77.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count        720.000000                720.000000   720.000000   720.000000
# mean          48.466667                 49.041667    46.934722   252.236111
# std           10.255783                 11.434201    10.026247    46.307190
# ...

# %% [markdown]
# ### Circasia

# %%
Quindio_Cicasia_resultados = Quindio.loc[(Quindio['ESTU_COD_RESIDE_MCPIO'] == '63190') | (Quindio['ESTU_COD_RESIDE_MCPIO'] == 63190)] 
Quindio_Cicasia_resultados.describe()
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                  266.0            266.000000        266.000000
# mean                 63190.0             52.067669         50.007519
# std                      0.0              9.816579         11.108383
# min                  63190.0             28.000000         22.000000
# 25%                  63190.0             45.000000         42.000000
# 50%                  63190.0             53.000000         50.000000
# 75%                  63190.0             59.000000         57.000000
# max                  63190.0             74.000000         77.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count        266.000000                266.000000   266.000000   266.000000
# mean          48.041353                 48.469925    46.939850   247.210526
# std            9.984241                 11.397163     9.405145    45.079477
# ...

# %% [markdown]
# ### Cordoba

# %%
Quindio_Cordoba_resultados = Quindio.loc[(Quindio['ESTU_COD_RESIDE_MCPIO'] == '63212') | (Quindio['ESTU_COD_RESIDE_MCPIO'] == 63212)]
Quindio_Cordoba_resultados.describe()
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                   75.0             75.000000         75.000000
# mean                 63212.0             47.200000         45.720000
# std                      0.0              8.277289          8.406175
# min                  63212.0             26.000000         28.000000
# 25%                  63212.0             40.000000         39.000000
# 50%                  63212.0             48.000000         45.000000
# 75%                  63212.0             54.000000         51.500000
# max                  63212.0             63.000000         66.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count         75.000000                 75.000000    75.000000    75.000000
# mean          41.400000                 42.213333    43.600000   220.453333
# std            8.432562                  8.104542     6.898884    33.249789
# ...

# %% [markdown]
# ### Filandia

# %%
Quindio_Filandia_resultados = Quindio.loc[(Quindio['ESTU_COD_RESIDE_MCPIO'] == '63272') | (Quindio['ESTU_COD_RESIDE_MCPIO'] == 63272)]
Quindio_Filandia_resultados.describe()
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                  166.0            166.000000        166.000000
# mean                 63272.0             50.921687         50.969880
# std                      0.0             10.167084         11.760965
# min                  63272.0             28.000000         26.000000
# 25%                  63272.0             43.000000         44.000000
# 50%                  63272.0             51.000000         52.000000
# 75%                  63272.0             58.750000         58.000000
# max                  63272.0             76.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count        166.000000                166.000000   166.000000   166.000000
# mean          48.638554                 47.608434    45.873494   246.271084
# std           10.240831                 11.187533     9.968539    46.244987
# ...

# %% [markdown]
# ### Génova

# %%
Quindio_Genova_resultados = Quindio.loc[(Quindio['ESTU_COD_RESIDE_MCPIO'] == '63302') | (Quindio['ESTU_COD_RESIDE_MCPIO'] == 63302)]
Quindio_Genova_resultados.describe()
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                   75.0             75.000000         75.000000
# mean                 63302.0             49.266667         45.840000
# std                      0.0              9.601989         10.988987
# min                  63302.0             29.000000         23.000000
# 25%                  63302.0             43.000000         39.500000
# 50%                  63302.0             48.000000         45.000000
# 75%                  63302.0             56.000000         52.000000
# max                  63302.0             72.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count         75.000000                 75.000000    75.000000    75.000000
# mean          45.866667                 45.400000    42.266667   231.346667
# std            9.604804                 11.324453     9.239067    44.685233
# ...

# %% [markdown]
# ### Tebaida

# %%
Quindio_Tebaida_resultados = Quindio.loc[(Quindio['ESTU_COD_RESIDE_MCPIO'] == '63401') | (Quindio['ESTU_COD_RESIDE_MCPIO'] == 63401)]
Quindio_Tebaida_resultados.describe()
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                  455.0            455.000000        455.000000
# mean                 63401.0             49.868132         47.279121
# std                      0.0              9.588458          9.844110
# min                  63401.0             28.000000          0.000000
# 25%                  63401.0             43.000000         41.000000
# 50%                  63401.0             50.000000         47.000000
# 75%                  63401.0             56.500000         54.000000
# max                  63401.0             77.000000         76.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count        455.000000                455.000000   455.000000   455.000000
# mean          44.380220                 44.338462    43.628571   231.230769
# std            8.729314                 10.741032     8.569260    40.265385
# ...

# %% [markdown]
# ### Montenegro

# %%
Quindio_Montenegro_resultados = Quindio.loc[(Quindio['ESTU_COD_RESIDE_MCPIO'] == '63470') | (Quindio['ESTU_COD_RESIDE_MCPIO'] == 63470)]
Quindio_Montenegro_resultados.describe()
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                  411.0            411.000000        411.000000
# mean                 63470.0             50.732360         49.024331
# std                      0.0              9.711266         11.208420
# min                  63470.0              0.000000          0.000000
# 25%                  63470.0             44.000000         41.500000
# 50%                  63470.0             52.000000         50.000000
# 75%                  63470.0             58.000000         57.000000
# max                  63470.0             76.000000         80.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count        411.000000                411.000000   411.000000   411.000000
# mean          45.630170                 45.712895    45.133820   237.868613
# std            9.456677                 11.078228    10.463367    44.825214
# ...

# %% [markdown]
# ### Pijao

# %%
Quindio_Pijao_resultados = Quindio.loc[(Quindio['ESTU_COD_RESIDE_MCPIO'] == '63548') | (Quindio['ESTU_COD_RESIDE_MCPIO'] == 63548)]
Quindio_Pijao_resultados.describe()
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                   98.0             98.000000         98.000000
# mean                 63548.0             52.500000         50.051020
# std                      0.0              9.377809         11.661349
# min                  63548.0             31.000000         19.000000
# 25%                  63548.0             48.000000         45.000000
# 50%                  63548.0             52.000000         51.500000
# 75%                  63548.0             58.750000         57.000000
# max                  63548.0             76.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count         98.000000                 98.000000    98.000000    98.000000
# mean          48.510204                 48.214286    46.836735   247.938776
# std            9.378903                 10.522680     9.676940    43.658897
# ...

# %% [markdown]
# ### Quimbaya

# %%
Quindio_Quimbaya_resultados = Quindio.loc[(Quindio['ESTU_COD_RESIDE_MCPIO'] == '63594') | (Quindio['ESTU_COD_RESIDE_MCPIO'] == 63594)]
Quindio_Quimbaya_resultados.describe()
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                  383.0            383.000000        383.000000
# mean                 63594.0             51.825065         49.916449
# std                      0.0              9.921324         11.236082
# min                  63594.0             27.000000         21.000000
# 25%                  63594.0             44.000000         42.000000
# 50%                  63594.0             52.000000         50.000000
# 75%                  63594.0             59.000000         58.000000
# max                  63594.0            100.000000         81.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count        383.000000                383.000000   383.000000   383.000000
# mean          47.733681                 47.678851    46.712794   245.456919
# std            9.684396                 11.584145    10.455892    45.575352
# ...

# %% [markdown]
# ### Salento

# %%
Quindio_Salento_resultados = Quindio.loc[(Quindio['ESTU_COD_RESIDE_MCPIO'] == '63690') | (Quindio['ESTU_COD_RESIDE_MCPIO'] == 63690)]
Quindio_Salento_resultados.describe()
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                   86.0             86.000000         86.000000
# mean                 63690.0             52.313953         48.593023
# std                      0.0             10.552125         11.779721
# min                  63690.0             25.000000         22.000000
# 25%                  63690.0             45.000000         41.000000
# 50%                  63690.0             52.500000         48.500000
# 75%                  63690.0             59.000000         57.000000
# max                  63690.0             75.000000         75.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count         86.000000                 86.000000    86.000000    86.000000
# mean          46.523256                 48.139535    44.930233   242.965116
# std            8.995066                 11.595296     9.315125    45.264828
# ...

# %% [markdown]
# ### Buenavista

# %%
Quindio_Buenavista_resultados = Quindio.loc[(Quindio['ESTU_COD_RESIDE_MCPIO'] == '63111') | (Quindio['ESTU_COD_RESIDE_MCPIO'] == 63111)]
Quindio_Buenavista_resultados.describe()
# Out:
#        ESTU_COD_RESIDE_MCPIO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count                   26.0             26.000000         26.000000
# mean                 63111.0             50.423077         50.769231
# std                      0.0              9.170270         10.351068
# min                  63111.0             34.000000         29.000000
# 25%                  63111.0             43.250000         42.250000
# 50%                  63111.0             51.500000         51.000000
# 75%                  63111.0             56.000000         57.000000
# max                  63111.0             67.000000         69.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count         26.000000                 26.000000    26.000000    26.000000
# mean          45.153846                 49.153846    44.153846   242.615385
# std           10.975217                 10.030722     7.587845    44.017339
# ...

# %% [markdown]
# ##  Puntaje promedio por género, estrato de la ubicación del  colegio, estrato de donde vive el estudiante

# %% [markdown]
# ## Puntaje por genero

# %% [markdown]
# ### Femenino

# %%
Genero = ['ESTU_GENERO', 'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PUNT_GLOBAL']
Gender_dt= Datos[Genero]
Genero_femenino_resultados = Gender_dt.loc[(Gender_dt['ESTU_GENERO'] == 'F')]
Genero_masculino_resultados = Gender_dt.loc[(Gender_dt['ESTU_GENERO'] == 'M')]
Genero_femenino_resultados.describe()
# Out:
#        PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# count         276572.000000     276572.000000     276572.000000
# mean              52.054760         49.680571         47.418904
# std               10.148094         11.308919         10.150748
# min                0.000000          0.000000          0.000000
# 25%               45.000000         42.000000         40.000000
# 50%               52.000000         49.000000         47.000000
# 75%               59.000000         57.000000         54.000000
# max              100.000000        100.000000        100.000000
#
#        PUNT_SOCIALES_CIUDADANAS    PUNT_INGLES    PUNT_GLOBAL
# count             276572.000000  276378.000000  276572.000000
# mean                  47.833277      46.414722     245.143091
# std                   11.638367      11.044695      47.492473
# min                    0.000000       0.000000       0.000000
# 25%                   39.000000      39.000000     209.000000
# ...

# %% [markdown]
# ### Masculino

# %%
Genero_masculino_resultados.describe()
# Out:
#        PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# count         228292.000000     228292.000000     228292.000000
# mean              52.280325         52.642107         49.140504
# std               10.169633         11.844271         10.832714
# min                0.000000          0.000000          0.000000
# 25%               45.000000         44.000000         41.000000
# 50%               53.000000         53.000000         49.000000
# 75%               59.000000         61.000000         57.000000
# max              100.000000        100.000000        100.000000
#
#        PUNT_SOCIALES_CIUDADANAS    PUNT_INGLES    PUNT_GLOBAL
# count             228292.000000  228152.000000  228292.000000
# mean                  48.719267      47.451348     252.228527
# std                   12.343772      11.604649      49.833117
# min                    0.000000       0.000000       0.000000
# 25%                   39.000000      39.000000     214.000000
# ...

# %%
Datos['FAMI_ESTRATOVIVIENDA'].unique()
# Out:
# array(['Estrato 2', 'Estrato 3', 'Estrato 1', 'Sin Estrato', 'Estrato 5',
#        'Estrato 6', 'Estrato 4', nan], dtype=object)

# %%
# Filtrar por estrato específico
estrato_1 = Datos[Datos['FAMI_ESTRATOVIVIENDA'] == 'Estrato 1']
estrato_2 = Datos[Datos['FAMI_ESTRATOVIVIENDA'] == 'Estrato 2']
estrato_3 = Datos[Datos['FAMI_ESTRATOVIVIENDA'] == 'Estrato 3']
estrato_4 = Datos[Datos['FAMI_ESTRATOVIVIENDA'] == 'Estrato 4']
estrato_5 = Datos[Datos['FAMI_ESTRATOVIVIENDA'] == 'Estrato 5']
estrato_6 = Datos[Datos['FAMI_ESTRATOVIVIENDA'] == 'Estrato 6']
sin_estrato = Datos[Datos['FAMI_ESTRATOVIVIENDA'] == 'Sin Estrato']

# Comprobar la cantidad de filas en cada estrato (opcional)
print("Filas en Estrato 1:", len(estrato_1))
print("Filas en Estrato 2:", len(estrato_2))
print("Filas en Estrato 3:", len(estrato_3))
print("Filas en Estrato 4:", len(estrato_4))
print("Filas en Estrato 5:", len(estrato_5))
print("Filas en Estrato 6:", len(estrato_6))
print("Filas en Sin Estrato:", len(sin_estrato))
# Out:
# Filas en Estrato 1: 152852
# Filas en Estrato 2: 182322
# Filas en Estrato 3: 103550
# Filas en Estrato 4: 23463
# Filas en Estrato 5: 7019
# Filas en Estrato 6: 3083
# Filas en Sin Estrato: 15631

# %% [markdown]
# ### Puntajes por Estrato

# %%
media_estrato_1 = estrato_1['PUNT_GLOBAL'].mean()
media_estrato_2 = estrato_2['PUNT_GLOBAL'].mean()
media_estrato_3 = estrato_3['PUNT_GLOBAL'].mean()
media_estrato_4 = estrato_4['PUNT_GLOBAL'].mean()
media_estrato_5 = estrato_5['PUNT_GLOBAL'].mean()
media_estrato_6 = estrato_6['PUNT_GLOBAL'].mean()
media_sin_estrato = sin_estrato['PUNT_GLOBAL'].mean()
print("Media de puntuación global para Estrato 1:", media_estrato_1)
print("Media de puntuación global para Estrato 2:", media_estrato_2)
print("Media de puntuación global para Estrato 3:", media_estrato_3)
print("Media de puntuación global para Estrato 4:", media_estrato_4)
print("Media de puntuación global para Estrato 5:", media_estrato_5)
print("Media de puntuación global para Estrato 6:", media_estrato_6)
print("Media de puntuación global para sin estrato:", media_sin_estrato)
# Out:
# Media de puntuación global para Estrato 1: 236.9594051762489
# Media de puntuación global para Estrato 2: 250.3750726736214
# Media de puntuación global para Estrato 3: 262.37280540801544
# Media de puntuación global para Estrato 4: 272.97008055235904
# Media de puntuación global para Estrato 5: 268.8753383672888
# Media de puntuación global para Estrato 6: 253.64742134284788
# Media de puntuación global para sin estrato: 209.56010491971082

# %%
# Calcular el promedio de PUNT_GLOBAL para cada estrato
promedios_por_estrato = Datos.groupby('FAMI_ESTRATOVIVIENDA')['PUNT_GLOBAL'].mean().reset_index()

# Crear la gráfica de barras
plt.figure(figsize=(10, 6))
sns.barplot(data=promedios_por_estrato, x='FAMI_ESTRATOVIVIENDA', y='PUNT_GLOBAL', palette="viridis")

# Personalizar la gráfica
plt.title('Promedio de Puntaje Global por Estrato de Vivienda')
plt.xlabel('Estrato de Vivienda')
plt.ylabel('Puntaje Global Promedio')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\juand\AppData\Local\Temp\ipykernel_6064\538291673.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=promedios_por_estrato, x='FAMI_ESTRATOVIVIENDA', y='PUNT_GLOBAL', palette="viridis")

# %% [markdown]
# #  Estudiantes Venezolanos

# %% [markdown]
# ## Promedio de Puntaje

# %%
Nacionalidad = ['ESTU_NACIONALIDAD', 'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PUNT_GLOBAL']
Pais = Datos[Nacionalidad]
Venezuela = Pais.loc[(Pais['ESTU_NACIONALIDAD'] == 'VENEZUELA')]  # Select Venezuela nationality
Venezuela.describe()
# Out:
#        PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# count           2927.000000       2927.000000       2927.000000
# mean              51.117526         48.582849         47.053297
# std                9.775218         11.288694         10.105690
# min                0.000000          0.000000          0.000000
# 25%               44.000000         41.000000         40.000000
# 50%               51.000000         48.000000         47.000000
# 75%               58.000000         56.000000         54.000000
# max               78.000000        100.000000        100.000000
#
#        PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count               2927.000000  2927.000000  2927.000000
# mean                  46.989067    45.965494   241.229587
# std                   11.162530    11.765967    45.865474
# min                    0.000000     0.000000     0.000000
# 25%                   39.000000    39.000000   207.000000
# ...

# %%
Venezuela_dep = Datos[['ESTU_NACIONALIDAD', 'ESTU_COD_RESIDE_DEPTO']]
Venezuela_dep_total = Venezuela_dep.loc[(Venezuela_dep['ESTU_NACIONALIDAD'] == 'VENEZUELA')]
Venezuela_dep_total.describe()

Cont_Dep_Ven = Venezuela_dep_total['ESTU_COD_RESIDE_DEPTO'].value_counts()

# %%
plt.figure(figsize=(15, 6))
Cont_Dep_Ven.plot(kind='barh')
plt.title('Distribución de estudiantes venezolanos por departamento')
plt.xlabel('Cantidad de estudiantes')
plt.ylabel('Codigo del Departamento')  
plt.show()

# %% [markdown]
# # Grupos étnicos

# %%
Etnia = ['ESTU_TIENEETNIA', 'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PUNT_GLOBAL']
Etnia_t = Datos[Etnia]
Ethnic_resultados = Etnia_t.loc[(Etnia_t['ESTU_TIENEETNIA'] == 'Si')]
Ethnic_resultados.describe()
# Out:
#        PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# count          31941.000000      31941.000000      31941.000000
# mean              46.062115         44.391691         42.509752
# std                9.758773         10.719052          9.221779
# min                0.000000          0.000000          0.000000
# 25%               39.000000         37.000000         36.000000
# 50%               45.000000         43.000000         41.000000
# 75%               53.000000         51.000000         48.000000
# max              100.000000        100.000000        100.000000
#
#        PUNT_SOCIALES_CIUDADANAS   PUNT_INGLES   PUNT_GLOBAL
# count              31941.000000  31609.000000  31941.000000
# mean                  41.757240     41.730109    217.640149
# std                   10.501241      8.618526     42.646425
# min                    0.000000      0.000000      0.000000
# 25%                   34.000000     36.000000    185.000000
# ...

# %%
Etn_Dep_df = Datos[['ESTU_TIENEETNIA', 'ESTU_COD_RESIDE_DEPTO']]
Etn_Dep_Tot = Etn_Dep_df.loc[(Etn_Dep_df['ESTU_TIENEETNIA'] == 'Si')]

Cont_Dep_Etn = Etn_Dep_Tot['ESTU_COD_RESIDE_DEPTO'].value_counts()

plt.figure(figsize=(10, 6))
Cont_Dep_Etn.plot(kind='barh')
plt.title('Distribución de grupos étnicos por departamento')
plt.xlabel('Número de estudiantes')
plt.ylabel('Codigo del Departamento')
plt.xticks(rotation=45)  
plt.show()

# %% [markdown]
# # PRUEBAS DE HIPOTESIS

# %% [markdown]
# ### Este código realiza una prueba t de dos muestras independientes para comparar las medias de los puntajes globales entre los grupos de Montenegro y Calarcá.

# %% [markdown]
# #### El valor negativo del estadístico t indica que la media de los puntajes del grupo de Montenegro es menor que la media de los puntajes del grupo de Calarcá.
# #### La magnitud de este valor (-5.08) sugiere una diferencia significativa entre las dos medias.
# #### El valor p es muy pequeño (aproximadamente 4.48x10^{10−7}), lo que indica que la probabilidad de que la diferencia observada entre las medias sea debida al azar es extremadamente baja. Dado que el valor p es mucho menor que el nivel de significancia (0.05), rechazamos la hipótesis nula.
# #### Debido a que el valor p es muy bajo, hay suficiente evidencia estadística para rechazar la hipótesis nula, lo que significa que las medias de los puntajes globales de los grupos de Montenegro y Calarcá son significativamente diferentes.

# %%
# Comparación de medias entre Montenegro y Calarcá usando prueba t
t_stat, p_value = ttest_ind(
    Quindio_Montenegro_resultados['PUNT_GLOBAL'],
    Quindio_Calarca_resultados['PUNT_GLOBAL'],
    equal_var=True  # Usa False si las varianzas son diferentes
)

# Resultados
alpha = 0.05  # Nivel de significancia
print(f'Estadístico t: {t_stat}')
print(f'Valor p: {p_value}')
if p_value < alpha:
    print("Rechazamos la hipótesis nula: las medias son significativamente diferentes.")
else:
    print("No rechazamos la hipótesis nula: no hay evidencia suficiente para decir que las medias son diferentes.")
# Out:
# Estadístico t: -5.0770668158963845
# Valor p: 4.480387816773078e-07
# Rechazamos la hipótesis nula: las medias son significativamente diferentes.

# %% [markdown]
# #### Estadístico t: -7.993783516419305:
#
# #### El valor negativo del estadístico t indica que la media de los puntajes del grupo femenino es menor que la media de los puntajes del grupo masculino.
# #### La magnitud del valor (-7.99) es bastante grande, lo que sugiere una diferencia significativa entre las medias de los dos grupos.
#
# #### El valor p es extremadamente pequeño (1.57×10−15), lo que indica que la probabilidad de obtener una diferencia tan extrema si las medias fueran iguales es prácticamente cero. Como el valor p es mucho menor que el nivel de significancia (0.05), podemos rechazar la hipótesis nula.
#
# #### "Rechazamos la hipótesis nula: las medias son significativamente diferentes." Dado que el valor p es extremadamente bajo, hay suficiente evidencia estadística para rechazar la hipótesis nula, lo que significa que hay una diferencia estadísticamente significativa entre los puntajes globales de los estudiantes de género femenino y masculino en el departamento de Quindío.
#
#
# #### El valor negativo del estadístico t indica que los estudiantes femeninos tienen puntajes globales más bajos que los masculinos, aunque esta diferencia es estadísticamente significativa. La diferencia en los puntajes globales entre los géneros es sustancial y no es atribuible al azar, según los resultados de la prueba t.

# %%
Gen_Quindio = Datos[['ESTU_GENERO', 'ESTU_COD_RESIDE_DEPTO', 'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PUNT_GLOBAL']]
Gen_Quindio = Gen_Quindio.loc[(Gen_Quindio['ESTU_COD_RESIDE_DEPTO'] == '63') | (Gen_Quindio['ESTU_COD_RESIDE_DEPTO'] == 63)]

Gen_F_Quindio = Gen_Quindio.loc[(Gen_Quindio['ESTU_GENERO'] == 'F')]
Gen_M_Quindio = Gen_Quindio.loc[(Gen_Quindio['ESTU_GENERO'] == 'M')]

X_Female_Quindio_mean = Gen_F_Quindio['PUNT_GLOBAL'].mean()
n_Female_Quindio_count = Gen_F_Quindio['PUNT_GLOBAL'].count()

# Comparación de medias entre Montenegro y Calarcá usando prueba t
t_stat_2, p_value_2 = ttest_ind(
    Gen_F_Quindio['PUNT_GLOBAL'],
    Gen_M_Quindio['PUNT_GLOBAL'],
    equal_var=True  # Usa False si las varianzas son diferentes
)

# Resultados
alpha = 0.05  # Nivel de significancia
print(f'Estadístico t: {t_stat_2}')
print(f'Valor p: {p_value_2}')
if p_value_2 < alpha:
    print("Rechazamos la hipótesis nula: las medias son significativamente diferentes.")
else:
    print("No rechazamos la hipótesis nula: no hay evidencia suficiente para decir que las medias son diferentes.")
# Out:
# Estadístico t: -7.993783516419305
# Valor p: 1.5665395279140614e-15
# Rechazamos la hipótesis nula: las medias son significativamente diferentes.

# %%
# Plot
data = pd.DataFrame({
    'PUNT_GLOBAL': pd.concat([
        Quindio_Montenegro_resultados['PUNT_GLOBAL'],
        Quindio_Calarca_resultados['PUNT_GLOBAL'],
        Gen_F_Quindio['PUNT_GLOBAL'],
        Gen_M_Quindio['PUNT_GLOBAL']
    ]),
    'municipality': ['Montenegro'] * len(Quindio_Montenegro_resultados) +
                 ['Calarca'] * len(Gen_F_Quindio) +
                 ['Female'] * len(Quindio_Calarca_resultados) +
                 ['Male'] * len(Gen_M_Quindio)
})

# Crear el boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='municipality', y='PUNT_GLOBAL', data=data)
plt.title('Comparación de las puntuaciones globales entre Montenegro y Calarcá, y de género masculino y femenino en el Quindío')
plt.xlabel('Municipio')
plt.ylabel('Puntuación global')
plt.show()

# %%
ata = pd.DataFrame({
    'PUNT_GLOBAL': pd.concat([
        Quindio_Montenegro_resultados['PUNT_GLOBAL'],
        Quindio_Calarca_resultados['PUNT_GLOBAL'],
        Gen_F_Quindio['PUNT_GLOBAL'],
        Gen_M_Quindio['PUNT_GLOBAL']
    ]),
    'municipality': ['Montenegro'] * len(Quindio_Montenegro_resultados) +
                 ['Calarca'] * len(Gen_F_Quindio) +
                 ['Female'] * len(Quindio_Calarca_resultados) +
                 ['Male'] * len(Gen_M_Quindio)
})

# Crear el boxplot
plt.figure(figsize=(10, 6))
sns.boxenplot(x='municipality', y='PUNT_GLOBAL', data=data)
plt.title('Comparación de las puntuaciones globales entre Montenegro y Calarcá, y de género masculino y femenino en el Quindío')
plt.xlabel('Municipio')
plt.ylabel('Puntuación global')
plt.show()
